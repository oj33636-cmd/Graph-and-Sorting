# %% [markdown]
# **Graph**

# %% [markdown]
# 05
#
# 인접 행렬. 인접 행렬은 간선 존재 여부를 O(1)에확인할 수 있어 더 효율적이기 때문이다.

# %% [markdown]
# 06
# 인접 리스트. 인접 리스트는 실제 존재하는 간선만 저장하므로 공간 효율이 높기 때문이다.

# %% [markdown]
# 08
# 1번

# %% [markdown]
# **12**
# (1)
#
# ![IMG_7277.jpeg](data:image/jpeg;base64,...)
# (2)
#
# ![IMG_7278.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 16
# (1)
#
#
# topologicalSort(G):
#     for each v ∈ G.V:
#         in_degree[v] ← 0
#
#     for each u ∈ G.V:
#         for each v ∈ u.adj:
#             in_degree[v] ← in_degree[v] + 1
#
#     S ← empty stack
#     for each v ∈ G.V:
#         if in_degree[v] == 0:
#             S.push(v)
#
#     while S is not empty:
#         u ← S.pop()
#         print(u)
#
#         for each v ∈ u.adj:
#             in_degree[v] ← in_degree[v] - 1
#             if in_degree[v] == 0:
#                 S.push(v)
#
#
# (2) 4가지

# %% [markdown]
# 17
#
# ![IMG_7280.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 18
#
#
# ![IMG_7281.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 22
#
# Negative Cycle이 있는 경우.
# 사이클을 돌 때마다 총 경로 거리가 계속해서 감소하므로 최단 경로가 계속 작아지게 되어 정의할 수 없다. 벨만-포드 알고리즘은 이 경우 negative cycle의 존재 여부를 감지하고 오류를 반환한다.

# %% [markdown]
# **Sorting**

# %% [markdown]
# 05
#
# (1)
#
# [12, 70, 30, 20, 55, 25]
#
# [12 | 70, 30, 20, 55, 25]
#
# [12, 20 | 30, 70, 55, 25]
#
# [12, 20, 25 | 70, 55, 30]
#
# [12, 20, 25, 30 | 55, 70]
#
# [12, 20, 25, 30, 55 | 70]
#
# [12, 20, 25, 30, 55, 70]
#
# (2)
#
# [12, 70, 30, 20, 55, 25]
#
# [12, 70, 30, 20, 55, 25] $\rightarrow$ [12, 30, 70, 20, 55, 25] $\rightarrow$ [12, 30, 20, 70, 55, 25] $\rightarrow$ [12, 30, 20, 55, 70, 25] $\rightarrow$ [12, 30, 20, 55, 25 | 70]
#
# [12, 30, 20, 55, 25 | 70] $\rightarrow$ [12, 20, 30, 55, 25 | 70] $\rightarrow$ [12, 20, 30, 25, 55 | 70]
#
# [12, 20, 30, 25 | 55, 70] $\rightarrow$ [12, 20, 25, 30 | 55, 70]
#
# [12, 20, 25 | 30, 55, 70]
#
# [12, 20, 25, 30, 55, 70]
#
# (3)
#
# [12, 70, 30, 20, 55, 25]
#
# [12, 70 | 30, 20, 55, 25]
#
# [12, 30, 70 | 20, 55, 25]
#
# [12, 20, 30, 70 | 55, 25]
#
# [12, 20, 30, 55, 70 | 25]
#
# [12, 20, 25, 30, 55, 70]
#
# [12, 20, 25, 30, 55, 70]

# %% [markdown]
# 06
#
# (1)
#
# [12, 70, 30, 20, 55, 25, 40, 50]
#
# [12, 70, 30, 20] / [55, 25, 40, 50]
#
# [12, 70] / [30, 20] // [55, 25] / [40, 50]
#
# [12] / [70] / [30] / [20] // [55] / [25] / [40] / [50]
#
# (2)
#
# [12, 70, 30, 20, 55, 25, 40, 50]
#
# [55, 50, 40, 20, 12, 25, 30 | 70]
#
# [50, 30, 40, 20, 12, 25 | 55, 70]
#
# [40, 30, 25, 20, 12 | 50, 55, 70]
#
# [30, 20, 25, 12 | 40, 50, 55, 70]
#
# [25, 20, 12 | 30, 40, 50, 55, 70]
#
# [20, 12 | 25, 30, 40, 50, 55, 70]
#
# [12 | 20, 25, 30, 40, 50, 55, 70]
#
# [12, 20, 25, 30, 40, 50, 55, 70]
#
# (3)
#
# [12, 70, 30, 20, 55, 25, 40, 50]
#
# [12] [70, 30, 20, 55, 25, 40, 50]
#
# 12 [50, 30, 20, 55, 25, 40] [70]
#
# 12 [40, 30, 20, 25] [50] [55] 70
#
# 12 [25, 30, 20] [40] 50 55 70
#
# 12 [20] [25] [30] 40 50 55 70
#
# [12, 20, 25, 30, 40, 50, 55, 70]
